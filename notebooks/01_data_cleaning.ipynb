# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load any dataset
file = "../data/cleaned/adani_monthly_cleaned.csv"
df = pd.read_csv(file)

df.columns = df.columns.str.strip()     # remove spaces
print(df.head())
print(df.info())
print(df.describe())

# Auto-detect date column
date_col = [c for c in df.columns if "date" in c.lower()][0]

df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=[date_col]).sort_values(date_col)

# Plot all numerical trends
num_cols = df.select_dtypes(include=['float','int']).columns

for col in num_cols:
    plt.figure(figsize=(12,4))
    plt.plot(df[date_col], df[col])
    plt.title(f"Trend — {col}")
    plt.grid(); plt.show()
# Out:
#          date  monthly_sales
# 0  2016-01-31  1039831516800
# 1  2016-02-29  1035801820800
# 2  2016-03-31  1031838566400
# 3  2016-04-30  1027663113600
# 4  2016-05-31  1023712819200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           108 non-null    object
#  1   monthly_sales  108 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB
# None
#        monthly_sales
# count   1.080000e+02
# mean    8.228909e+11
# std     1.267683e+11
# min     6.118489e+11
# 25%     7.135816e+11
# 50%     8.223978e+11
# 75%     9.316146e+11
# max     1.039832e+12

# %%
import pandas as pd
file=input("CSV inside data/raw/: ")
df=pd.read_csv(f"data/raw/{file}")
df.head(), df.info(), df.describe()
# Out:
# 🔍 DATA CLEANING NOTEBOOK
# Put raw CSVs in: data/raw/
# CSV filename in data/raw/ (e.g. train.csv):  data/raw/balajin.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 16
#      13 csv_name = input("CSV filename in data/raw/ (e.g. train.csv): ").strip()
#      14 raw_path = os.path.join("data", "raw", csv_name)
# ---> 16 df, date_col, target_col = load_and_clean_csv(raw_path)
#      18 print("\n✅ Cleaning complete")
#      19 print("📅 Detected date column :", date_col)
#
# File ~\Downloads\Mini_Project_Shravani_Harel_Sales_Forecasting\src\data_prep.py:64, in load_and_clean_csv(filename)
#      61     path = DATA_RAW_DIR / filename
#      63 if not path.exists():
# ---> 64     raise FileNotFoundError(f"File not found in data/raw: {path}")
#      66 df = pd.read_csv(path)
#      67 df.columns = df.columns.str.strip()
#
# FileNotFoundError: File not found in data/raw: C:\Users\lalee\Downloads\Mini_Project_Shravani_Harel_Sales_Forecasting\data\raw\data\raw\data\raw\balajin.csv
