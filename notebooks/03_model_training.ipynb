# %%
from src.model_training import train_model_from_csv
f=input("CSV inside data/raw/: ")
train_model_from_csv(f"data/raw/{f}",force_retrain=True)
# Out:
# 🤖 MODEL TRAINING NOTEBOOK
# Raw CSV in data/raw/ to train on (e.g. train.csv):  adani.csv
# 📥 Training new model from data\raw\adani.csv ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 15
#      12 csv_name = input("Raw CSV in data/raw/ to train on (e.g. train.csv): ").strip()
#      13 raw_path = os.path.join("data", "raw", csv_name)
# ---> 15 model = train_model_from_csv(raw_path, force_retrain=True)
#      17 print("\n✅ Training complete.")
#      18 print(f"Model saved at: {MODEL_PATH}")
#
# File ~\Downloads\Mini_Project_Shravani_Harel_Sales_Forecasting\src\model_training.py:34, in train_model_from_csv(filename, force_retrain)
#      30     return model
#      32 print(f"📥 Training new model from {filename} ...")
# ---> 34 df, date_col, target_col = load_and_clean_csv(filename)
#      35 ts = build_daily_series(df, date_col, target_col)
# ...
