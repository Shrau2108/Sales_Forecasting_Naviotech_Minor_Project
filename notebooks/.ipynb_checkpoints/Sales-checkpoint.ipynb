# %%
# ==========================================
# 📓 SALES FORECASTING MASTER NOTEBOOK
# EDA → Feature Engineering → ML Training → Forecast Generation
# ==========================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings("ignore")

# ---------- Load Dataset ----------
df = pd.read_csv("../data/cleaned/adani_monthly_cleaned.csv")  # or balaji/monthly, adani, etc.
df["Date"] = pd.to_datetime(df["date"])
df = df.sort_values("Date")

print(df.head())
print(df.describe())
# Out:
#          date  monthly_sales       Date
# 0  2016-01-31  1039831516800 2016-01-31
# 1  2016-02-29  1035801820800 2016-02-29
# 2  2016-03-31  1031838566400 2016-03-31
# 3  2016-04-30  1027663113600 2016-04-30
# 4  2016-05-31  1023712819200 2016-05-31
#        monthly_sales                 Date
# count   1.080000e+02                  108
# mean    8.228909e+11  2020-07-15 13:20:00
# min     6.118489e+11  2016-01-31 00:00:00
# 25%     7.135816e+11  2018-04-22 12:00:00
# 50%     8.223978e+11  2020-07-15 12:00:00
# 75%     9.316146e+11  2022-10-07 18:00:00
# max     1.039832e+12  2024-12-31 00:00:00
# std     1.267683e+11                  NaN

# %%
from src.pipeline import run_full_pipeline

csv = input("Enter CSV file in data/raw/: ")
days = int(input("Forecast days: "))
force = input("Retrain model? (y/n): ").lower()=="y"

df = run_full_pipeline(f"../data/raw/{csv}",days,force)
df.tail()
# Out:
# Enter CSV file in data/raw/:  adani.csv
# Forecast days:  80
# Retrain model? (y/n):  y
# 📦 Installing missing package: scikit-learn
# ✅ All dependencies available.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[47], line 7
#       4 days = int(input("Forecast days: "))
#       5 force = input("Retrain model? (y/n): ").lower()=="y"
# ----> 7 df = run_full_pipeline(f"data/raw/{csv}",days,force)
#       8 df.tail()
#
# File ~\Downloads\Mini_Project_Shravani_Harel_Sales_Forecasting\src\pipeline.py:30, in run_full_pipeline(csv_filename, forecast_days, force_retrain)
#      26 # -----------------------------
#      27 # 1. Validate input dataset
#      28 # -----------------------------
#      29 if not os.path.exists(csv_filename):
# ---> 30     raise FileNotFoundError(f"❌ CSV not found → {csv_filename}")
#      32 # -----------------------------
# ...
