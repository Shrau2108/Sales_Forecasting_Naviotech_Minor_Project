# %%
from src.forecast_future import generate_future_forecast
df=generate_future_forecast(int(input("Forecast days: ")))
df.tail()
# Out:
# 🔮 FORECAST TESTING NOTEBOOK
# How many days to forecast? (30–365):  80
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 14
#      10 print("🔮 FORECAST TESTING NOTEBOOK")
#      12 days = int(input("How many days to forecast? (30–365): "))
# ---> 14 forecast_df = generate_future_forecast(days)
#      15 forecast_path = DATA_FEATURE_DIR / "future_sales_forecast.csv"
#      17 print(f"\n✅ Forecast generated and saved to: {forecast_path}")
#
# File ~\Downloads\Mini_Project_Shravani_Harel_Sales_Forecasting\src\forecast_future.py:14, in generate_future_forecast(days)
#       9 """
#      10 Uses trained model + last feature rows to roll forward N days.
#      11 """
#      12 days = days or DEFAULT_FORECAST_DAYS
# ---> 14 model = joblib.load(MODEL_PATH)
#      16 feature_path = DATA_FEATURE_DIR / "final_training_dataset.csv"
# ...
